# %%
pip install datasets transformers

# %%
pip install datasets

# %%
from datasets import load_dataset
import pandas as pd
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

# %%
filename = "Amod/mental_health_counseling_conversations"
dataset_df = load_dataset(filename)
# Out:
# ...
# Generating train split:   0%|          | 0/3512 [00:00<?, ? examples/s]

# %%
dataset_df= pd.DataFrame(dataset_df)

# %%
dataset_df.head()
# Out:
#                                                train
# 0  {'Context': 'I'm going through some things wit...
# 1  {'Context': 'I'm going through some things wit...
# 2  {'Context': 'I'm going through some things wit...
# 3  {'Context': 'I'm going through some things wit...
# 4  {'Context': 'I'm going through some things wit...

# %%
examples = dataset_df.to_dict()

# %%
len(dataset_df)
# Out:
# 3512

# %%
model_pretrained = "Felladrin/Llama-68M-Chat-v1"

# %%
model = AutoModelForQuestionAnswering.from_pretrained(model_pretrained)
tokenizer= AutoTokenizer.from_pretrained(model_pretrained)
# Out:
# config.json:   0%|          | 0.00/597 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/272M [00:00<?, ?B/s]
# Some weights of LlamaForQuestionAnswering were not initialized from the model checkpoint at Felladrin/Llama-68M-Chat-v1 and are newly initialized: ['embed_tokens.weight', 'layers.0.input_layernorm.weight', 'layers.0.mlp.down_proj.weight', 'layers.0.mlp.gate_proj.weight', 'layers.0.mlp.up_proj.weight', 'layers.0.post_attention_layernorm.weight', 'layers.0.self_attn.k_proj.weight', 'layers.0.self_attn.o_proj.weight', 'layers.0.self_attn.q_proj.weight', 'layers.0.self_attn.v_proj.weight', 'layers.1.input_layernorm.weight', 'layers.1.mlp.down_proj.weight', 'layers.1.mlp.gate_proj.weight', 'layers.1.mlp.up_proj.weight', 'layers.1.post_attention_layernorm.weight', 'layers.1.self_attn.k_proj.weight', 'layers.1.self_attn.o_proj.weight', 'layers.1.self_attn.q_proj.weight', 'layers.1.self_attn.v_proj.weight', 'norm.weight', 'qa_outputs.bias', 'qa_outputs.weight']
# ...

# %%
if "context" in examples and "response" in examples:
  text = examples["context"][0] + examples["response"][0]
elif "instruction" in examples and "response" in examples:
  text = examples["instruction"][0] + examples["response"][0]
elif "input" in examples and "output" in examples:
  text = examples["input"][0] + examples["output"][0]

# %%
qa_pipeline = pipeline(
    "question-answering",
    model=model,
    tokenizer=tokenizer
)
question = "What is the main topic of the conversation?"
result = qa_pipeline({
    'context': text,
    'question': question
})
examples = {"context": ["This is a context."], "response": ["This is a response."]}
res = qa_pipeline(question=prompt, context=text)
print(res['answer'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-dc621de95f92> in <cell line: 7>()
#       6 question = "What is the main topic of the conversation?"
#       7 result = qa_pipeline({
# ----> 8     'context': text,
#       9     'question': question
#      10 })
#
# NameError: name 'text' is not defined
